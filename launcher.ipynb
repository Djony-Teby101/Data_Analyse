# %% [markdown]
# # Chargement, Exploration et Selection avec

# %%
import pandas as pd
import numpy as np

df= pd.read_csv('ventes.txt')
print("DataFrame chargé")
# Out:
# DataFrame chargé

# %%
print(df.head(3))
print(df.columns)
# Out:
#   Magasin  Annee      Ville  Chiffre_Affaires
# 0       A   2021      Paris            150000
# 1       B   2021       Lyon             98000
# 2       C   2021  Marseille            120000
# Index(['Magasin', 'Annee', 'Ville', 'Chiffre_Affaires'], dtype='object')

# %%
# Selectionner des données de l'année.
ventes_2022=df[df['Annee']==2022]
ventes_2022
# Out:
#   Magasin  Annee      Ville  Chiffre_Affaires
# 3       A   2022      Paris            180000
# 4       B   2022       Lyon            105000
# 5       C   2022  Marseille            135000
