# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
np.random.seed(42)
n_transactions=500

# %%
#dates=[datetime(2024, 1, 1)+ timedelta(days=np.random.randint(0,90)) for _ in range(n_transactions)]

# %%
# Génération des données brutes
dates = [datetime(2024, 1, 1) + timedelta(days=np.random.randint(0, 90)) for _ in range(n_transactions)]

data = {
    'transaction_id': list(range(1001, 1001 + n_transactions)),
    'date': dates,
    'montant': np.random.uniform(-5000, 10000, n_transactions).round(2),
    'categorie': np.random.choice(['Alimentation', 'Transport', 'Loisirs', 'Salaire', '???', '', None], n_transactions),
    'description': [f"ACHAT {np.random.choice(['CARREFOUR', 'UBER', 'NETFLIX', 'SALAIRIE', ''])}" for _ in range(n_transactions)],
    'type_client': np.random.choice(['particulier', 'pro', 'particulier', 'particulier', None], n_transactions),
    'devise': np.random.choice(['EUR', 'EUR', 'EUR', 'USD', 'GBP', ''], n_transactions)
}

df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#    transaction_id       date  montant categorie      description  type_client  \
# 0            1001 2024-01-22  1430.88      None    ACHAT NETFLIX          pro
# 1            1002 2024-03-27 -2264.97   Loisirs  ACHAT CARREFOUR  particulier
# 2            1003 2024-02-18  9134.51       ???       ACHAT UBER  particulier
# 3            1004 2024-03-08  6326.02   Salaire  ACHAT CARREFOUR  particulier
# 4            1005 2024-01-15 -1879.63   Loisirs       ACHAT UBER  particulier
#
#   devise
# 0    EUR
# 1    EUR
# 2
# 3    EUR
# 4    EUR

# %%
#Recuperer une  section du dataframe.
df.loc[0:3, 'description']=np.nan

# %%
df.head(10)
# Out:
#    transaction_id       date  montant     categorie     description  \
# 0            1001 2024-01-22  1430.88          None             NaN
# 1            1002 2024-03-27 -2264.97       Loisirs             NaN
# 2            1003 2024-02-18  9134.51           ???             NaN
# 3            1004 2024-03-08  6326.02       Salaire             NaN
# 4            1005 2024-01-15 -1879.63       Loisirs      ACHAT UBER
# 5            1006 2024-03-05    65.66     Transport   ACHAT NETFLIX
# 6            1007 2024-02-23  7145.11     Transport          ACHAT
# 7            1008 2024-01-30  5435.16       Salaire  ACHAT SALAIRIE
# 8            1009 2024-01-20  6486.76  Alimentation   ACHAT NETFLIX
# 9            1010 2024-02-02  1618.02  Alimentation      ACHAT UBER
#
#    type_client devise
# 0          pro    EUR
# 1  particulier    EUR
# 2  particulier
# 3  particulier    EUR
# 4  particulier    EUR
# 5         None    USD
# 6         None    GBP
# 7         None    USD
# 8  particulier    EUR
# 9          pro    EUR

# %%
df.loc[6:9, 'montant']=9999.9 #Valeur Aberrantes.

# %%
df.head(10)
# Out:
#    transaction_id       date  montant     categorie     description  \
# 0            1001 2024-01-22  1430.88          None             NaN
# 1            1002 2024-03-27 -2264.97       Loisirs             NaN
# 2            1003 2024-02-18  9134.51           ???             NaN
# 3            1004 2024-03-08  6326.02       Salaire             NaN
# 4            1005 2024-01-15 -1879.63       Loisirs      ACHAT UBER
# 5            1006 2024-03-05    65.66     Transport   ACHAT NETFLIX
# 6            1007 2024-02-23  9999.90     Transport          ACHAT
# 7            1008 2024-01-30  9999.90       Salaire  ACHAT SALAIRIE
# 8            1009 2024-01-20  9999.90  Alimentation   ACHAT NETFLIX
# 9            1010 2024-02-02  9999.90  Alimentation      ACHAT UBER
#
#    type_client devise
# 0          pro    EUR
# 1  particulier    EUR
# 2  particulier
# 3  particulier    EUR
# 4  particulier    EUR
# 5         None    USD
# 6         None    GBP
# 7         None    USD
# 8  particulier    EUR
# 9          pro    EUR
